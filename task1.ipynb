# %%
import numpy as np
import matplotlib.pyplot as plt
import urllib
import cv2
# %matplotlib inline

# %%
image_url = 'https://i.pinimg.com/originals/03/2b/e9/032be9c6131b0b72f8cc99f4823fa46b.jpg'

# %%
req = urllib.request.urlopen(image_url)

# %%
array = np.asarray(bytearray(req.read()), dtype=np.uint8)

# %%
image = cv2.imdecode(array, -1)

# %%
plt.imshow(image, cmap='gray')

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_image, cmap='gray')

# %%
histogram = cv2.calcHist([gray_image], [0], None, [256], [0, 256])

# %%
plt.figure(figsize=(8, 5))
plt.plot(histogram, color='black')
plt.xlabel('Яркость пикселей')
plt.ylabel('Частота')
plt.title('Гистограмма изображения')
plt.show()

# %%
equalized_image = cv2.equalizeHist(gray_image)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
axes[0].set_title('Исходное изображение')
axes[0].axis('off')

axes[1].imshow(gray_image, cmap='gray')
axes[1].set_title('Градации серого')
axes[1].axis('off')

axes[2].imshow(equalized_image, cmap='gray')
axes[2].set_title('Выравненная гистограмма')
axes[2].axis('off')

plt.show()
